# %%
## fancyimpute requires TensorFlow
import pandas as pd
pd.options.display.max_columns=100
import numpy as np
import argparse
from directory import data, images

# %%
clean = pd.read_pickle("{}/clean.pkl".format(data))
raw = pd.read_pickle("{}/census_raw.pkl".format(data))

# %%
suspect = ['24033807200', '24033807000', '12086000109', '22071013400', '48201100000', '23005000300', '12099001700']
clean[clean['geoid'].isin(suspect)]
# Out:
#        population_total2017  age_median2017  household_income_median2017  \
# 14130               14944.0            40.8                      65160.0
# 16328                3251.0            53.4                      57708.0
# 28425                9734.0            33.9                      50954.0
# 29381                3833.0            64.9                      54041.0
# 29827                6357.0            42.7                     122091.0
# 29862                6121.0            35.5                      54508.0
# 65153                4278.0            31.7                      39278.0
#
#        home_value_median2017  structure_year_median2017  \
# 14130               170100.0                       61.0
# 16328               365700.0                       29.0
# 28425               167300.0                       62.0
# 29381               176300.0                       31.0
# 29827               325000.0                       48.0
# ...

# %%
from sklearn.decomposition import NMF
import sklearn.preprocessing as prepro
drop_cols = ['population_total2017', 'household_income_median2017',
       'home_value_median2017', 'housing_units_total2017', 'geoid', 'oz', 'LICadj', 'eligible']

# %%
e = clean[clean['eligible'] == 1]
ozs = clean[clean['oz'] == 1]

# %%
plt.rcParams['font.size'] = 16

# %%
X = e.drop(columns=drop_cols)
mm_scaler = prepro.MinMaxScaler()
std_X = mm_scaler.fit_transform(X.values)

for n in range(2, 11):
    paxNMF = NMF(n_components=n)
    w = paxNMF.fit_transform(std_X)
    h = paxNMF.components_
    cluster_plots(paxNMF.components_, X.columns)
    plt.savefig("{}/NMF{}_e.png".format(images, n), dpi=120, transparent=True)

# %%
mean_eligible = np.mean(e, axis = 0)
mean_oz = np.mean(ozs, axis = 0)

# %%
## figure out how to show this
## maybe the difference between the means, with a KS-test?
f, ax = plt.subplots(figsize = (7, 9))

centroid_plot(ax, mean_oz.index[7:-4], mean_oz[7:-4], kwargs={'color':palette.as_hex()[0], 'alpha':0.9, 'label':"mean designated"})

centroid, features = mean_eligible[7:-4], mean_eligible.index[7:-4]
y = np.arange(len(centroid))
kwargs={'color':palette.as_hex()[1], 'alpha':0.9, 'label':"mean eligible"}
bars = ax.barh(y + 0.8, centroid, tick_label=features, **kwargs)
ax.set_xlim(np.min(centroid) - 0.3, np.max(centroid) + 0.7)

ax.legend()

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
plt.style.use('seaborn-ticks')
palette = sns.color_palette(palette='deep')
# %matplotlib inline
from paxplot import centroid_plot, cluster_plots

sns.set_style(style={'axes.spines.left': True,
 'axes.spines.bottom': True})
sns.set_context(rc = {'patch.linewidth': 0.0})

# %%
f = "percent_poverty_2017"

# %%
fig, ax = plt.subplots(figsize=(9,9))
b = 30

y = clean[f].values
y_e = e[f].values
ax.hist(y_e, bins=b, density=True, alpha=0.9, color=palette.as_hex()[0], label='All eligible tracts')
ax.hist(y, bins=b, density=True, alpha=0.7, color=palette.as_hex()[1], label="Designated OZs")

ax.axvline(np.mean(y), linestyle="solid", color='k', alpha=0.8, label="OZ average")
ax.axvline(np.mean(y_e), linestyle="dotted", color='k', alpha=0.8, label="Eligible tract average")

ax.set_title("{}".format(f), fontsize=16)
ax.set_ylabel("Frequency", fontsize=14)
ax.set_yticklabels([])

ax.legend(fontsize=14)
ax.set_facecolor('white')
